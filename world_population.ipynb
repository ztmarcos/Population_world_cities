# %%
import pandas as pd
import numpy as np

def get_data(): 
    df = pd.read_csv('/Users/marcoszavalatorres/Documents/DS/population cities of the world/world-country-populations.csv')
    return df

# %%
# Load the data
df = get_data()

# Display the first few rows of the dataframe
print(df.head())

# Check the shape of the dataframe
print("Shape:", df.shape)

# Check the column names
print("Columns:", df.columns)

# Check the data types of each column
print("Data Types:", df.dtypes)

# Check the summary statistics of the numerical columns
print("Summary Statistics:")
print(df.describe())
# Out:
#    population_in_2023  population_in_2022       city     country  \
# 0            37194105            37274002      Tokyo       Japan
# 1            32941309            32065760      Delhi       India
# 2            29210808            28516903   Shanghai       China
# 3            23209616            22478117      Dhaka  Bangladesh
# 4            22619736            22429799  Sao Paulo      Brazil
#
#    population_growthRate type
# 0                -0.0021    w
# 1                 0.0273    w
# 2                 0.0243    w
# 3                 0.0325    w
# 4                 0.0085    w
# Shape: (778, 6)
# Columns: Index(['population_in_2023', 'population_in_2022', 'city', 'country',
#        'population_growthRate', 'type'],
#       dtype='object')
# Data Types: population_in_2023         int64
# population_in_2022         int64
# city                      object
# country                   object
# population_growthRate    float64
# type                      object
# ...

# %%
# Create df_1 with country name and population columns
df_1 = df[['city', 'population_in_2022', 'population_in_2023']]

# Display the first few rows of df_1
print(df_1.head())
# Out:
#         city  population_in_2022  population_in_2023
# 0      Tokyo            37274002            37194105
# 1      Delhi            32065760            32941309
# 2   Shanghai            28516903            29210808
# 3      Dhaka            22478117            23209616
# 4  Sao Paulo            22429799            22619736

# %%
df_1.head(10).plot(x='city', y=['population_in_2022', 'population_in_2023'], kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
import matplotlib.pyplot as plt

df_2.head(10).plot(x='city', y=['population_in_2022', 'population_in_2023'], kind='bar')
plt.title('Cities with Decreased Population')
plt.show()

# %%
# Sort the dataframe by growth rate in descending order
df_sorted = df.sort_values(by='population_growthRate', ascending=False)

# Get the top 10 cities with the highest growth rate
top_10_cities = df_sorted.head(10)['city']

# Print the top 10 cities
print(top_10_cities)
# Out:
# 694           Lokoja
# 472        Bujumbura
# 480          Xiongan
# 718            Bunia
# 754              Ibb
# 447    Abomey-Calavi
# 122          Kampala
# 455            Nnewi
# 745          Malanje
# 418           Mwanza
# Name: city, dtype: object
